# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='SHOP'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.05))

model.add(Dense(15, activation='relu'))
model.add(Dropout(0.05))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0111 - val_loss: 0.0095
# Epoch 2/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0113 - val_loss: 0.0199
# Epoch 3/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0086 - val_loss: 0.0101
# Epoch 4/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0122 - val_loss: 0.0060
# Epoch 5/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0115 - val_loss: 0.0140
# Epoch 6/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0115 - val_loss: 0.0110
# Epoch 7/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0098 - val_loss: 0.0203
# Epoch 8/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0107 - val_loss: 0.0118
# Epoch 9/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0096 - val_loss: 0.0183
# Epoch 10/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0084 - val_loss: 0.0103
# Epoch 11/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0107 - val_loss: 0.0124
# Epoch 12/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0112 - val_loss: 0.0107
# Epoch 13/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0095 - val_loss: 0.0174
# Epoch 14/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0116 - val_loss: 0.0322
# Epoch 15/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0091 - val_loss: 0.0180
# Epoch 16/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 17/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0117 - val_loss: 0.0138
# Epoch 18/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0086 - val_loss: 0.0182
# Epoch 19/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0086 - val_loss: 0.0199
# Epoch 20/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0085 - val_loss: 0.0318
# Epoch 21/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0097 - val_loss: 0.0150
# Epoch 22/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0096 - val_loss: 0.0069
# Epoch 23/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0090 - val_loss: 0.0220
# Epoch 24/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0080 - val_loss: 0.0196
# Epoch 25/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0093 - val_loss: 0.0175
# Epoch 26/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0081 - val_loss: 0.0223
# Epoch 27/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0097 - val_loss: 0.0105
# Epoch 28/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 29/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0076 - val_loss: 0.0285
# Epoch 30/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0099 - val_loss: 0.0184
# Epoch 31/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0098 - val_loss: 0.0265
# Epoch 32/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0096 - val_loss: 0.0063
# Epoch 33/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0089 - val_loss: 0.0049
# Epoch 34/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0090 - val_loss: 0.0063
# Epoch 35/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0080 - val_loss: 0.0132
# Epoch 36/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0086 - val_loss: 0.0096
# Epoch 37/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0088 - val_loss: 0.0057
# Epoch 38/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 39/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0089 - val_loss: 0.0059
# Epoch 40/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0073 - val_loss: 0.0035
# Epoch 41/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0083 - val_loss: 0.0026
# Epoch 42/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 0.0129
# Epoch 43/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 44/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0110 - val_loss: 0.0215
# Epoch 45/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0079 - val_loss: 0.0261
# Epoch 46/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0096 - val_loss: 0.0085
# Epoch 47/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0101 - val_loss: 0.0201
# Epoch 48/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0097 - val_loss: 0.0171
# Epoch 49/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0095 - val_loss: 0.0067
# Epoch 50/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0089 - val_loss: 0.0151

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.05))

forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.05))
forecast_model.add(Dense(1))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[170.71489189],
#        [170.30640339],
#        [169.90199051],
#        [169.5369752 ],
#        [169.18719359],
#        [168.87558086],
#        [168.57398559],
#        [168.28971284],
#        [168.02006174],
#        [167.75752326],
#        [167.5060316 ],
#        [167.26626137],
#        [167.03343683],
#        [166.8074189 ],
#        [166.59077162],
#        [166.37881199],
#        [166.17320225],
#        [165.97317271],
#        [165.78086087]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
