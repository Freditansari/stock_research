# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='BA'
stock_parameter ='Low'
epoch_number=100
epoch_number_forecast=100

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps, validate for 1 steps
# Epoch 1/100
# 232/232 [==============================] - 5s 21ms/step - loss: 0.1011 - val_loss: 0.2247
# Epoch 2/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0589 - val_loss: 0.1859
# Epoch 3/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0487 - val_loss: 0.1189
# Epoch 4/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0381 - val_loss: 0.0984
# Epoch 5/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0345 - val_loss: 0.0628
# Epoch 6/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0282 - val_loss: 0.0473
# Epoch 7/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0294 - val_loss: 0.0482
# Epoch 8/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0274 - val_loss: 0.0439
# Epoch 9/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0253 - val_loss: 0.0314
# Epoch 10/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0227 - val_loss: 0.0153
# Epoch 11/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0225 - val_loss: 0.0199
# Epoch 12/100
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0191 - val_loss: 0.0172
# Epoch 13/100
# 229/232 [============================>.] - ETA: 0s - loss: 0.019232/232 [==============================] - 2s 10ms/step - loss: 0.0193 - val_loss: 0.0186
# Epoch 14/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0185 - val_loss: 0.0136
# Epoch 15/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0168 - val_loss: 0.0084
# Epoch 16/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0180 - val_loss: 0.0062
# Epoch 17/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0171 - val_loss: 0.0090
# Epoch 18/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0162 - val_loss: 0.0064
# Epoch 19/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0147 - val_loss: 0.0069
# Epoch 20/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0144 - val_loss: 0.0067
# Epoch 21/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0183 - val_loss: 0.0055
# Epoch 22/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0135 - val_loss: 0.0048
# Epoch 23/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0168 - val_loss: 0.0032
# Epoch 24/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0123 - val_loss: 0.0051
# Epoch 25/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0143 - val_loss: 0.0063
# Epoch 26/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0136 - val_loss: 0.0051
# Epoch 27/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0144 - val_loss: 0.0054
# Epoch 28/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0114 - val_loss: 0.0056
# Epoch 29/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0115 - val_loss: 0.0068
# Epoch 30/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0115 - val_loss: 0.0031
# Epoch 31/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0114 - val_loss: 0.0092
# Epoch 32/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0093 - val_loss: 0.0042
# Epoch 33/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0141 - val_loss: 0.0017
# Epoch 34/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0129 - val_loss: 0.0135
# Epoch 35/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0139 - val_loss: 0.0070
# Epoch 36/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0127 - val_loss: 0.0034
# Epoch 37/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0123 - val_loss: 0.0040
# Epoch 38/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0123 - val_loss: 0.0020
# Epoch 39/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0112 - val_loss: 0.0023
# Epoch 40/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0103 - val_loss: 0.0036
# Epoch 41/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0120 - val_loss: 0.0056
# Epoch 42/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0100 - val_loss: 0.0045
# Epoch 43/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0123 - val_loss: 0.0013
# Epoch 44/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0127 - val_loss: 4.4762e-06
# Epoch 45/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0104 - val_loss: 0.0018
# Epoch 46/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0122 - val_loss: 0.0035
# Epoch 47/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0134 - val_loss: 0.0037
# Epoch 48/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 0.0036
# Epoch 49/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0121 - val_loss: 0.0033
# Epoch 50/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0118 - val_loss: 2.5566e-04
# Epoch 51/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0091 - val_loss: 0.0031
# Epoch 52/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 0.0027
# Epoch 53/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0096 - val_loss: 0.0023
# Epoch 54/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0106 - val_loss: 9.7847e-04
# Epoch 55/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0094 - val_loss: 0.0019
# Epoch 56/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0121 - val_loss: 0.0044
# Epoch 57/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0120 - val_loss: 0.0071
# Epoch 58/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 59/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0102 - val_loss: 0.0022
# Epoch 60/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0113 - val_loss: 0.0026
# Epoch 61/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0095 - val_loss: 0.0032
# Epoch 62/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 0.0036
# Epoch 63/100
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0102 - val_loss: 0.0013
# Epoch 64/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0116 - val_loss: 0.0020
# Epoch 65/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0081 - val_loss: 0.0022
# Epoch 66/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 0.0020
# Epoch 67/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 2.3169e-05
# Epoch 68/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 69/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 70/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0101 - val_loss: 6.5142e-04
# Epoch 71/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0084 - val_loss: 0.0021
# Epoch 72/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0092 - val_loss: 0.0073
# Epoch 73/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0083 - val_loss: 0.0011
# Epoch 74/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0092 - val_loss: 8.2166e-04
# Epoch 75/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0102 - val_loss: 0.0027
# Epoch 76/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 8.2335e-04
# Epoch 77/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 7.5211e-05
# Epoch 78/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0096 - val_loss: 0.0017
# Epoch 79/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 6.5208e-04
# Epoch 80/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 0.0014
# Epoch 81/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0080 - val_loss: 7.5511e-04
# Epoch 82/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0082 - val_loss: 0.0014
# Epoch 83/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0089 - val_loss: 0.0016
# Epoch 84/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0092 - val_loss: 0.0036
# Epoch 85/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110 - val_loss: 0.0023
# Epoch 86/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 3.4517e-04
# Epoch 87/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 9.8523e-05
# Epoch 88/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 0.0026
# Epoch 89/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0071 - val_loss: 0.0034
# Epoch 90/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0087 - val_loss: 0.0032
# Epoch 91/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 92/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 3.9984e-05
# Epoch 93/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0072 - val_loss: 6.0588e-05
# Epoch 94/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0063 - val_loss: 8.2067e-05
# Epoch 95/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0091 - val_loss: 0.0051
# Epoch 96/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0095 - val_loss: 0.0047
# Epoch 97/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0097 - val_loss: 0.0031
# Epoch 98/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0090 - val_loss: 5.3846e-04
# Epoch 99/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0101 - val_loss: 3.0637e-04
# Epoch 100/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0091 - val_loss: 7.6376e-04

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/100
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0877
# Epoch 2/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0458
# Epoch 3/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0367
# Epoch 4/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0397
# Epoch 5/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0316
# Epoch 6/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0351
# Epoch 7/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0337
# Epoch 8/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0328
# Epoch 9/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0308
# Epoch 10/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0315
# Epoch 11/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0319
# Epoch 12/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0279
# Epoch 13/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0305
# Epoch 14/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0312
# Epoch 15/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0286
# Epoch 16/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0272
# Epoch 17/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0241
# Epoch 18/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0291
# Epoch 19/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0267
# Epoch 20/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0249
# Epoch 21/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0251
# Epoch 22/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0260
# Epoch 23/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0265
# Epoch 24/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0231
# Epoch 25/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0247
# Epoch 26/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0238
# Epoch 27/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0237
# Epoch 28/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0269
# Epoch 29/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0260
# Epoch 30/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0251
# Epoch 31/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0255
# Epoch 32/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0264
# Epoch 33/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0255
# Epoch 34/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0225
# Epoch 35/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0224
# Epoch 36/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0225
# Epoch 37/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0263
# Epoch 38/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0208
# Epoch 39/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0225
# Epoch 40/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0178
# Epoch 41/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0215
# Epoch 42/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0189
# Epoch 43/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0204
# Epoch 44/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0225
# Epoch 45/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0203
# Epoch 46/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0185
# Epoch 47/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0185
# Epoch 48/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0247
# Epoch 49/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0180
# Epoch 50/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0176
# Epoch 51/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0171
# Epoch 52/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0175
# Epoch 53/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0176
# Epoch 54/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0182
# Epoch 55/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0168
# Epoch 56/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0177
# Epoch 57/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0152
# Epoch 58/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0161
# Epoch 59/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0150
# Epoch 60/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0157
# Epoch 61/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0135
# Epoch 62/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0177
# Epoch 63/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0145
# Epoch 64/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0129
# Epoch 65/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0136
# Epoch 66/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0127
# Epoch 67/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0113
# Epoch 68/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0115
# Epoch 69/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0107
# Epoch 70/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0106
# Epoch 71/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0125
# Epoch 72/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0120
# Epoch 73/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0122
# Epoch 74/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0106
# Epoch 75/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0096
# Epoch 76/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0109
# Epoch 77/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0100
# Epoch 78/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0133
# Epoch 79/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0087
# Epoch 80/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0084
# Epoch 81/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0086
# Epoch 82/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0113
# Epoch 83/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0077
# Epoch 84/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0093
# Epoch 85/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0090
# Epoch 86/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110
# Epoch 87/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0101
# Epoch 88/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0095
# Epoch 89/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0102
# Epoch 90/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0103
# Epoch 91/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0101
# Epoch 92/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0077
# Epoch 93/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0101
# Epoch 94/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0089
# Epoch 95/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0109
# Epoch 96/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110
# Epoch 97/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0079
# Epoch 98/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0076
# Epoch 99/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0092
# Epoch 100/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0077

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[141.01473009],
#        [141.60311934],
#        [142.09155486],
#        [142.4970538 ],
#        [142.8321334 ],
#        [143.11072314],
#        [143.34257716],
#        [143.53559003],
#        [143.69427039],
#        [143.82174976],
#        [143.9271858 ],
#        [144.01552576],
#        [144.08824329],
#        [144.14748747],
#        [144.19813537],
#        [144.240801  ],
#        [144.27455457],
#        [144.3001943 ],
#        [144.3219043 ]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
