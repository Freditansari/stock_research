# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='BA'
stock_parameter ='Low'
epoch_number=100
epoch_number_forecast=100

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/100
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0880 - val_loss: 0.2479
# Epoch 2/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0425 - val_loss: 0.1573
# Epoch 3/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0411 - val_loss: 0.2103
# Epoch 4/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0345 - val_loss: 0.1872
# Epoch 5/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0328 - val_loss: 0.1926
# Epoch 6/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0318 - val_loss: 0.1815
# Epoch 7/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0290 - val_loss: 0.1739
# Epoch 8/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0295 - val_loss: 0.1766
# Epoch 9/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0266 - val_loss: 0.1506
# Epoch 10/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0274 - val_loss: 0.1496
# Epoch 11/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0274 - val_loss: 0.1435
# Epoch 12/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0260 - val_loss: 0.1315
# Epoch 13/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0281 - val_loss: 0.1386
# Epoch 14/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0239 - val_loss: 0.1129
# Epoch 15/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0251 - val_loss: 0.1185
# Epoch 16/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0237 - val_loss: 0.1077
# Epoch 17/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0259 - val_loss: 0.1111
# Epoch 18/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0254 - val_loss: 0.1083
# Epoch 19/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0218 - val_loss: 0.0987
# Epoch 20/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0249 - val_loss: 0.1037
# Epoch 21/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0235 - val_loss: 0.0965
# Epoch 22/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0208 - val_loss: 0.0888
# Epoch 23/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0224 - val_loss: 0.0891
# Epoch 24/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0223 - val_loss: 0.0946
# Epoch 25/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0234 - val_loss: 0.1074
# Epoch 26/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0246 - val_loss: 0.0970
# Epoch 27/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0219 - val_loss: 0.0759
# Epoch 28/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0209 - val_loss: 0.0755
# Epoch 29/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0168 - val_loss: 0.0623
# Epoch 30/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0199 - val_loss: 0.0528
# Epoch 31/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0191 - val_loss: 0.0537
# Epoch 32/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0184 - val_loss: 0.0586
# Epoch 33/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0156 - val_loss: 0.0529
# Epoch 34/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0164 - val_loss: 0.0493
# Epoch 35/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0156 - val_loss: 0.0353
# Epoch 36/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0161 - val_loss: 0.0293
# Epoch 37/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0168 - val_loss: 0.0265
# Epoch 38/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0135 - val_loss: 0.0246
# Epoch 39/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0163 - val_loss: 0.0177
# Epoch 40/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0113 - val_loss: 0.0158
# Epoch 41/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0129 - val_loss: 0.0124
# Epoch 42/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0113 - val_loss: 0.0091
# Epoch 43/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0144 - val_loss: 0.0057
# Epoch 44/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 45/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0111 - val_loss: 0.0098
# Epoch 46/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0123 - val_loss: 0.0072
# Epoch 47/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0113 - val_loss: 0.0066
# Epoch 48/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0093 - val_loss: 0.0117
# Epoch 49/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0107 - val_loss: 0.0019
# Epoch 50/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0085 - val_loss: 0.0022
# Epoch 51/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0053
# Epoch 52/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0098 - val_loss: 0.0016
# Epoch 53/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0082 - val_loss: 0.0036
# Epoch 54/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0107 - val_loss: 0.0017
# Epoch 55/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 56/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 57/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0095 - val_loss: 7.9714e-04
# Epoch 58/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0095 - val_loss: 0.0039
# Epoch 59/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0079 - val_loss: 0.0103
# Epoch 60/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0084 - val_loss: 0.0119
# Epoch 61/100
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0102 - val_loss: 0.0048
# Epoch 62/100
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0081 - val_loss: 0.0016
# Epoch 63/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0098 - val_loss: 9.2847e-04
# Epoch 64/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0083 - val_loss: 0.0042
# Epoch 65/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0101 - val_loss: 0.0034
# Epoch 66/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0091 - val_loss: 3.8595e-04
# Epoch 67/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0084 - val_loss: 3.4206e-05
# Epoch 68/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0080 - val_loss: 0.0012
# Epoch 69/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0064 - val_loss: 9.3372e-04
# Epoch 70/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0060 - val_loss: 2.9680e-04
# Epoch 71/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0107 - val_loss: 0.0011
# Epoch 72/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0022
# Epoch 73/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0097 - val_loss: 0.0026
# Epoch 74/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0104 - val_loss: 0.0022
# Epoch 75/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 0.0034
# Epoch 76/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 77/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0092 - val_loss: 0.0069
# Epoch 78/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0086 - val_loss: 0.0051
# Epoch 79/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0099 - val_loss: 4.3797e-04
# Epoch 80/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0076 - val_loss: 0.0189
# Epoch 81/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0092 - val_loss: 0.0035
# Epoch 82/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0080 - val_loss: 0.0024
# Epoch 83/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0103 - val_loss: 7.1765e-04
# Epoch 84/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0077 - val_loss: 6.8960e-05
# Epoch 85/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0091 - val_loss: 8.8873e-04
# Epoch 86/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0090 - val_loss: 0.0083
# Epoch 87/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0133 - val_loss: 0.0026
# Epoch 88/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0094 - val_loss: 8.1784e-05
# Epoch 89/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0066 - val_loss: 2.1622e-04
# Epoch 90/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0080 - val_loss: 0.0021
# Epoch 91/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0075 - val_loss: 0.0022
# Epoch 92/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0078 - val_loss: 2.5813e-04
# Epoch 93/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0015
# Epoch 94/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0109 - val_loss: 0.0020
# Epoch 95/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0044
# Epoch 96/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0080 - val_loss: 0.0018
# Epoch 97/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 98/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0064 - val_loss: 0.0044
# Epoch 99/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0093 - val_loss: 2.5495e-04
# Epoch 100/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0053 - val_loss: 0.0054

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/100
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0911
# Epoch 2/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0528
# Epoch 3/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0438
# Epoch 4/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0373
# Epoch 5/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0351
# Epoch 6/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0322
# Epoch 7/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0336
# Epoch 8/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0306
# Epoch 9/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0284
# Epoch 10/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0288
# Epoch 11/100
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0266
# Epoch 12/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0283
# Epoch 13/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0235
# Epoch 14/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0260
# Epoch 15/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0255
# Epoch 16/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0221
# Epoch 17/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0205
# Epoch 18/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0209
# Epoch 19/100
# 230/232 [============================>.] - ETA: 0s - loss: 0.020232/232 [==============================] - 2s 8ms/step - loss: 0.0202
# Epoch 20/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0192
# Epoch 21/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0164
# Epoch 22/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0175
# Epoch 23/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0170
# Epoch 24/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0149
# Epoch 25/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0169
# Epoch 26/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0190
# Epoch 27/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0173
# Epoch 28/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0165
# Epoch 29/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0147
# Epoch 30/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0149
# Epoch 31/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0132
# Epoch 32/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0130
# Epoch 33/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0150
# Epoch 34/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0108
# Epoch 35/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0112
# Epoch 36/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0118
# Epoch 37/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0109
# Epoch 38/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0110
# Epoch 39/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0114
# Epoch 40/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.0120
# Epoch 41/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0115
# Epoch 42/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0121
# Epoch 43/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0100
# Epoch 44/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0116
# Epoch 45/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0108
# Epoch 46/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0110
# Epoch 47/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0098
# Epoch 48/100
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0091
# Epoch 49/100
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0107
# Epoch 50/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0125
# Epoch 51/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0084
# Epoch 52/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 53/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0103
# Epoch 54/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0114
# Epoch 55/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0089
# Epoch 56/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0077
# Epoch 57/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0097
# Epoch 58/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0099
# Epoch 59/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0084
# Epoch 60/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0124
# Epoch 61/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0096
# Epoch 62/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0099
# Epoch 63/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0095
# Epoch 64/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0071
# Epoch 65/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0089
# Epoch 66/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0112
# Epoch 67/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0080
# Epoch 68/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0097
# Epoch 69/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0106
# Epoch 70/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0074
# Epoch 71/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0089
# Epoch 72/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0102
# Epoch 73/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 74/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0084
# Epoch 75/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0078
# Epoch 76/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0093
# Epoch 77/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0071
# Epoch 78/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 79/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0096
# Epoch 80/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0081
# Epoch 81/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0068
# Epoch 82/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0073
# Epoch 83/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0079
# Epoch 84/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0080
# Epoch 85/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0069
# Epoch 86/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0061
# Epoch 87/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0065
# Epoch 88/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0061
# Epoch 89/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0058
# Epoch 90/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0098
# Epoch 91/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0060
# Epoch 92/100
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0069
# Epoch 93/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0064
# Epoch 94/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0065
# Epoch 95/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0084
# Epoch 96/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 97/100
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0064
# Epoch 98/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0070
# Epoch 99/100
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0058
# Epoch 100/100
# 232/232 [==============================] - 2s 6ms/step - loss: 0.0071

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[154.41653674],
#        [155.97125343],
#        [157.24396818],
#        [158.30535473],
#        [159.1889298 ],
#        [159.92820135],
#        [160.54718634],
#        [161.06609481],
#        [161.49917203],
#        [161.85749668],
#        [162.15766484],
#        [162.41084291],
#        [162.62310969],
#        [162.79965804],
#        [162.94911933],
#        [163.07384438],
#        [163.17570156],
#        [163.25593646],
#        [163.32205766]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
