# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='AMZN'
stock_parameter ='Daily gain'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)
stock['Daily gain']=stock['Adj Close'].pct_change(1)
stock=stock.dropna(axis=0)
stock
# Out:
#                High      Low     Open    Close      Volume     Adj Close  \
# Date
# 2019-05-07  28550.0  28250.0  28375.0  28300.0  11835400.0  27731.326172
# 2019-05-08  28500.0  27975.0  28000.0  28500.0  11812400.0  27927.308594
# 2019-05-09  28500.0  28125.0  28500.0  28150.0  25327300.0  27584.341797
# 2019-05-10  28400.0  28000.0  28050.0  28050.0  15226100.0  27486.351562
# 2019-05-13  28475.0  28000.0  28400.0  28050.0  12744100.0  27486.351562
# ...             ...      ...      ...      ...         ...           ...
# 2020-04-27  25100.0  24275.0  24700.0  24800.0  30220700.0  24800.000000
# 2020-04-28  24875.0  24025.0  24800.0  24150.0  36097600.0  24150.000000
# 2020-04-29  24250.0  24000.0  24125.0  24250.0  24232200.0  24250.000000
# 2020-04-30  26250.0  24400.0  24400.0  25850.0  34816200.0  25850.000000
# 2020-05-04  26500.0  25000.0  25750.0  26100.0  22899500.0  26100.000000
#
#             Daily gain
# Date
# 2019-05-07    0.007117
# 2019-05-08    0.007067
# 2019-05-09   -0.012281
# 2019-05-10   -0.003552
# 2019-05-13    0.000000
# ...                ...
# 2020-04-27    0.008130
# 2020-04-28   -0.026210
# 2020-04-29    0.004141
# 2020-04-30    0.065979
# 2020-05-04    0.009671
#
# [253 rows x 7 columns]

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Flatten

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(Dense(1, input_shape=(length, n_features)))
model.add(LSTM(64))
model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.4))
model.add(Dense(32, activation='sigmoid'))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 214 steps, validate for 1 steps
# Epoch 1/50
# 214/214 [==============================] - 5s 25ms/step - loss: 0.0505 - val_loss: 0.0041
# Epoch 2/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0358 - val_loss: 5.2324e-04
# Epoch 3/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0211 - val_loss: 0.0079
# Epoch 4/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0202 - val_loss: 4.5815e-07
# Epoch 5/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0175 - val_loss: 3.4404e-04
# Epoch 6/50
# 214/214 [==============================] - 2s 11ms/step - loss: 0.0157 - val_loss: 0.0013
# Epoch 7/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0133 - val_loss: 0.0126
# Epoch 8/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0119 - val_loss: 3.7077e-04
# Epoch 9/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0121 - val_loss: 0.0084
# Epoch 10/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0129 - val_loss: 7.1432e-06
# Epoch 11/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0107 - val_loss: 0.0033
# Epoch 12/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0108 - val_loss: 0.0082
# Epoch 13/50
# 214/214 [==============================] - 2s 7ms/step - loss: 0.0093 - val_loss: 0.0017
# Epoch 14/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0022
# Epoch 15/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0093 - val_loss: 4.1125e-04
# Epoch 16/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0088 - val_loss: 5.3602e-04
# Epoch 17/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0083 - val_loss: 7.8762e-05
# Epoch 18/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0087 - val_loss: 8.3580e-04
# Epoch 19/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0078 - val_loss: 0.0016
# Epoch 20/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0095 - val_loss: 2.9932e-04
# Epoch 21/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0083 - val_loss: 4.1498e-04
# Epoch 22/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0081 - val_loss: 0.0015
# Epoch 23/50
# 214/214 [==============================] - 1s 7ms/step - loss: 0.0080 - val_loss: 0.0029
# Epoch 24/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 25/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0080 - val_loss: 3.6913e-04
# Epoch 26/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0082 - val_loss: 6.7677e-06
# Epoch 27/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0079 - val_loss: 2.9435e-04
# Epoch 28/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 0.0031
# Epoch 29/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 4.7115e-05
# Epoch 30/50
# 214/214 [==============================] - 2s 7ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 31/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0077 - val_loss: 5.5904e-05
# Epoch 32/50
# 214/214 [==============================] - 2s 11ms/step - loss: 0.0078 - val_loss: 6.4079e-04
# Epoch 33/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0077 - val_loss: 0.0011
# Epoch 34/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0072 - val_loss: 0.0017
# Epoch 35/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0075 - val_loss: 0.0044
# Epoch 36/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0079 - val_loss: 1.2982e-04
# Epoch 37/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0066 - val_loss: 0.0014
# Epoch 38/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0073 - val_loss: 2.4622e-04
# Epoch 39/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0066 - val_loss: 0.0045
# Epoch 40/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0073 - val_loss: 1.9759e-04
# Epoch 41/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0070 - val_loss: 0.0018
# Epoch 42/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0069 - val_loss: 8.4170e-04
# Epoch 43/50
# 214/214 [==============================] - 2s 10ms/step - loss: 0.0068 - val_loss: 8.6098e-04
# Epoch 44/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0072 - val_loss: 8.2212e-04
# Epoch 45/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 46/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 3.8755e-04
# Epoch 47/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 48/50
# 214/214 [==============================] - 2s 8ms/step - loss: 0.0067 - val_loss: 0.0030
# Epoch 49/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0073 - val_loss: 4.9398e-06
# Epoch 50/50
# 214/214 [==============================] - 2s 9ms/step - loss: 0.0067 - val_loss: 0.0014

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
predictions
# Out:
#             Daily gain  Predictions
# Date
# 2020-04-03    0.015712     0.000301
# 2020-04-06    0.043676     0.000300
# 2020-04-07   -0.013949     0.000299
# 2020-04-08   -0.003537     0.000298
# 2020-04-09   -0.007099     0.000297
# 2020-04-13   -0.016979     0.000297
# 2020-04-14    0.002727     0.000296
# 2020-04-15   -0.005440     0.000296
# 2020-04-16   -0.044667     0.000295
# 2020-04-17    0.035305     0.000295
# 2020-04-20   -0.012903     0.000295
# 2020-04-21   -0.019757     0.000295
# 2020-04-22   -0.002907     0.000294
# 2020-04-23   -0.004859     0.000294
# 2020-04-24   -0.039062     0.000294
# 2020-04-27    0.008130     0.000294
# 2020-04-28   -0.026210     0.000294
# 2020-04-29    0.004141     0.000294
# 2020-04-30    0.065979     0.000294
# 2020-05-04    0.009671     0.000294

# %%
predictions['Predictions'].plot()

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(Dense(1, input_shape=(length, n_features)))
forecast_model.add(LSTM(64))
forecast_model.add(Flatten())
forecast_model.add(Dense(512, activation='sigmoid'))
forecast_model.add(Dropout(0.4))
forecast_model.add(Dense(32, activation='sigmoid'))
forecast_model.add(Dense(1))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 234 steps
# Epoch 1/50
# 234/234 [==============================] - 3s 15ms/step - loss: 0.0389
# Epoch 2/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0278
# Epoch 3/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0240
# Epoch 4/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0197
# Epoch 5/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0162
# Epoch 6/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0149
# Epoch 7/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0133
# Epoch 8/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0127
# Epoch 9/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0115
# Epoch 10/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0125
# Epoch 11/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0094
# Epoch 12/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0102
# Epoch 13/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0096
# Epoch 14/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0097
# Epoch 15/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0090
# Epoch 16/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0086
# Epoch 17/50
# 234/234 [==============================] - 2s 7ms/step - loss: 0.0090
# Epoch 18/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0091
# Epoch 19/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0083
# Epoch 20/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0092
# Epoch 21/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0084
# Epoch 22/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0085
# Epoch 23/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0091
# Epoch 24/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0090
# Epoch 25/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0077
# Epoch 26/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0077
# Epoch 27/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0074
# Epoch 28/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0079
# Epoch 29/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0077
# Epoch 30/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0072
# Epoch 31/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0080
# Epoch 32/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0084
# Epoch 33/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0079
# Epoch 34/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0075
# Epoch 35/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0078
# Epoch 36/50
# 234/234 [==============================] - 2s 10ms/step - loss: 0.0077
# Epoch 37/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0080
# Epoch 38/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0078
# Epoch 39/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0076
# Epoch 40/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0071
# Epoch 41/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0072
# Epoch 42/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0076
# Epoch 43/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0074
# Epoch 44/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0074
# Epoch 45/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0077
# Epoch 46/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0070
# Epoch 47/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0072
# Epoch 48/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0074
# Epoch 49/50
# 234/234 [==============================] - 2s 8ms/step - loss: 0.0071
# Epoch 50/50
# 234/234 [==============================] - 2s 9ms/step - loss: 0.0079

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[0.00029749],
#        [0.00029759],
#        [0.00029748],
#        [0.00029716],
#        [0.00029683],
#        [0.00029646],
#        [0.00029606],
#        [0.00029568],
#        [0.00029545],
#        [0.00029507],
#        [0.00029485],
#        [0.00029468],
#        [0.00029451],
#        [0.00029436],
#        [0.00029431],
#        [0.00029416],
#        [0.00029412],
#        [0.00029404],
#        [0.00029386]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')

# %%
forecast_df.plot()
