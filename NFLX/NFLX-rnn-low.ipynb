# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 500 #Days from now

stock_ticker ='NFLX'
stock_parameter ='Low'
epoch_number=25
epoch_number_forecast=25

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(150, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.5))
model.add(Dense(75, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 303 steps, validate for 1 steps
# Epoch 1/25
# 303/303 [==============================] - 8s 27ms/step - loss: 0.0896 - val_loss: 0.2580
# Epoch 2/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0434 - val_loss: 0.1955
# Epoch 3/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0370 - val_loss: 0.1885
# Epoch 4/25
# 303/303 [==============================] - 4s 15ms/step - loss: 0.0346 - val_loss: 0.1768
# Epoch 5/25
# 303/303 [==============================] - 6s 19ms/step - loss: 0.0363 - val_loss: 0.1376
# Epoch 6/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0324 - val_loss: 0.1012
# Epoch 7/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0313 - val_loss: 0.1187
# Epoch 8/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0307 - val_loss: 0.0729
# Epoch 9/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0297 - val_loss: 0.0832
# Epoch 10/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0319 - val_loss: 0.1008
# Epoch 11/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0290 - val_loss: 0.0629
# Epoch 12/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0277 - val_loss: 0.0617
# Epoch 13/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0281 - val_loss: 0.0546
# Epoch 14/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0275 - val_loss: 0.0553
# Epoch 15/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0264 - val_loss: 0.0828
# Epoch 16/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0269 - val_loss: 0.0521
# Epoch 17/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0303 - val_loss: 0.0635
# Epoch 18/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0283 - val_loss: 0.0782
# Epoch 19/25
# 303/303 [==============================] - 5s 15ms/step - loss: 0.0264 - val_loss: 0.0790
# Epoch 20/25
# 303/303 [==============================] - 4s 13ms/step - loss: 0.0252 - val_loss: 0.0648
# Epoch 21/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0297 - val_loss: 0.0322
# Epoch 22/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0257 - val_loss: 0.0721
# Epoch 23/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0279 - val_loss: 0.0398
# Epoch 24/25
# 303/303 [==============================] - 4s 14ms/step - loss: 0.0280 - val_loss: 0.0667
# Epoch 25/25
# 303/303 [==============================] - 4s 15ms/step - loss: 0.0266 - val_loss: 0.0737

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 323 steps
# Epoch 1/25
# 323/323 [==============================] - 4s 14ms/step - loss: 0.0358
# Epoch 2/25
# 323/323 [==============================] - 3s 9ms/step - loss: 0.0215
# Epoch 3/25
# 323/323 [==============================] - 3s 9ms/step - loss: 0.0167
# Epoch 4/25
# 323/323 [==============================] - 3s 8ms/step - loss: 0.0138
# Epoch 5/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0103
# Epoch 6/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0120
# Epoch 7/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0116
# Epoch 8/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0105
# Epoch 9/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0106
# Epoch 10/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0109
# Epoch 11/25
# 323/323 [==============================] - 2s 8ms/step - loss: 0.0099
# Epoch 12/25
# 323/323 [==============================] - 2s 8ms/step - loss: 0.0113
# Epoch 13/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0123
# Epoch 14/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0103
# Epoch 15/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0106
# Epoch 16/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0106
# Epoch 17/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0098
# Epoch 18/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0095
# Epoch 19/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0092
# Epoch 20/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0096
# Epoch 21/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0091
# Epoch 22/25
# 323/323 [==============================] - 2s 7ms/step - loss: 0.0089
# Epoch 23/25
# 323/323 [==============================] - 2s 8ms/step - loss: 0.0101
# Epoch 24/25
# 323/323 [==============================] - 2s 8ms/step - loss: 0.0093
# Epoch 25/25
# 323/323 [==============================] - 3s 8ms/step - loss: 0.0079

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[344.33017118],
#        [340.9286828 ],
#        [337.9297887 ],
#        [335.25978281],
#        [332.74827197],
#        [330.39471578],
#        [328.10996533],
#        [325.97215072],
#        [323.98498151],
#        [322.16851688],
#        [320.479854  ],
#        [318.92925145],
#        [317.57903009],
#        [316.32616447],
#        [315.19466151],
#        [314.17787145],
#        [313.28192195],
#        [312.48794457],
#        [311.77003638]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
