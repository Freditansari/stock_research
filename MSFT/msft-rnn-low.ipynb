# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='MSFT'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.05))
# model.add(Dense(50, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.05))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0297 - val_loss: 0.0499
# Epoch 2/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0157 - val_loss: 0.0254
# Epoch 3/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0108 - val_loss: 0.0046
# Epoch 4/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0075 - val_loss: 0.0049
# Epoch 5/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0057 - val_loss: 0.0149
# Epoch 6/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0083 - val_loss: 0.0028
# Epoch 7/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 8/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 9/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0072 - val_loss: 0.0040
# Epoch 10/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 11/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 12/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0070 - val_loss: 0.0012
# Epoch 13/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0066 - val_loss: 0.0022
# Epoch 14/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0050 - val_loss: 6.2294e-04
# Epoch 15/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0061 - val_loss: 0.0029
# Epoch 16/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0052 - val_loss: 9.2648e-04
# Epoch 17/50
# 211/212 [============================>.] - ETA: 0s - loss: 0.005212/212 [==============================] - 1s 7ms/step - loss: 0.0056 - val_loss: 2.7318e-04
# Epoch 18/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0058 - val_loss: 0.0025
# Epoch 19/50
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0070 - val_loss: 0.0020
# Epoch 20/50
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 21/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0059 - val_loss: 5.2970e-04
# Epoch 22/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0059 - val_loss: 0.0011
# Epoch 23/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0054 - val_loss: 0.0012
# Epoch 24/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0055 - val_loss: 7.8200e-04
# Epoch 25/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0058 - val_loss: 0.0030
# Epoch 26/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 27/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 0.0013
# Epoch 28/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0054 - val_loss: 2.3574e-05
# Epoch 29/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0055 - val_loss: 0.0010
# Epoch 30/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0050 - val_loss: 3.4079e-04
# Epoch 31/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 7.1115e-04
# Epoch 32/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 33/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 34/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 3.4750e-04
# Epoch 35/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 8.4352e-04
# Epoch 36/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 37/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 38/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 0.0028
# Epoch 39/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0047 - val_loss: 0.0020
# Epoch 40/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 41/50
# 212/212 [==============================] - 1s 5ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 42/50
# 212/212 [==============================] - 1s 6ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 43/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 44/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 45/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0057 - val_loss: 4.2041e-04
# Epoch 46/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0061 - val_loss: 4.0314e-04
# Epoch 47/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 2.0116e-05
# Epoch 48/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0052 - val_loss: 4.0693e-04
# Epoch 49/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 50/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0056 - val_loss: 7.9401e-04

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
# forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
# forecast_model.add(Dropout(0.2))
# forecast_model.add(Dense(50, activation='relu'))
# forecast_model.add(Dropout(0.2))
# forecast_model.add(Dense(15, activation='relu'))
# forecast_model.add(Dropout(0.2))
# forecast_model.add(Dense(5, activation='relu'))
# forecast_model.add(Dropout(0.2))
# forecast_model.add(Dense(1, activation='relu'))
# forecast_model.compile(optimizer='SGD', loss='mse')

# ####
forecast_model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.05))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.05))
forecast_model.add(Dense(1))
forecast_model.compile(optimizer='SGD', loss='mse')
# ####

# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.05))
# # model.add(Dense(50, activation='relu'))
# # model.add(Dropout(0.2))
# model.add(Dense(15, activation='relu'))
# model.add(Dropout(0.05))
# model.add(Dense(1))

forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0489
# Epoch 2/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0274
# Epoch 3/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0167
# Epoch 4/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0114
# Epoch 5/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0089
# Epoch 6/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0085
# Epoch 7/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0071
# Epoch 8/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0083
# Epoch 9/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0073
# Epoch 10/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0068
# Epoch 11/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0069
# Epoch 12/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0060
# Epoch 13/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0060
# Epoch 14/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0066
# Epoch 15/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0069
# Epoch 16/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0059
# Epoch 17/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0071
# Epoch 18/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0059
# Epoch 19/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0058
# Epoch 20/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0058
# Epoch 21/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0061
# Epoch 22/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0054
# Epoch 23/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0055
# Epoch 24/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0051
# Epoch 25/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0064
# Epoch 26/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0057
# Epoch 27/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0057
# Epoch 28/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0057
# Epoch 29/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0055
# Epoch 30/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0049
# Epoch 31/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0057
# Epoch 32/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0044
# Epoch 33/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0055
# Epoch 34/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0051
# Epoch 35/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0046
# Epoch 36/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0050
# Epoch 37/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0043
# Epoch 38/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0047
# Epoch 39/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0054
# Epoch 40/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0044
# Epoch 41/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0043
# Epoch 42/50
# 232/232 [==============================] - 1s 6ms/step - loss: 0.0047
# Epoch 43/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0045
# Epoch 44/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0047
# Epoch 45/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0049
# Epoch 46/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0045
# Epoch 47/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0039
# Epoch 48/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0040
# Epoch 49/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0042
# Epoch 50/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0045

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[172.39269966],
#        [172.07158422],
#        [171.74395086],
#        [171.39642195],
#        [171.03020777],
#        [170.64684433],
#        [170.26946806],
#        [169.89571464],
#        [169.54077917],
#        [169.20132428],
#        [168.8701726 ],
#        [168.52762159],
#        [168.21011696],
#        [167.90549135],
#        [167.61285616],
#        [167.34270601],
#        [167.0751775 ],
#        [166.83004557],
#        [166.61482935]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
