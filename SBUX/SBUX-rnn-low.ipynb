# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='SBUX'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 14s 65ms/step - loss: 0.0747 - val_loss: 0.0404
# Epoch 2/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0371 - val_loss: 0.0387
# Epoch 3/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0315 - val_loss: 0.0486
# Epoch 4/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0262 - val_loss: 0.0236
# Epoch 5/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0213 - val_loss: 0.0290
# Epoch 6/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0201 - val_loss: 0.0114
# Epoch 7/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0179 - val_loss: 0.0110
# Epoch 8/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0180 - val_loss: 0.0153
# Epoch 9/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0170 - val_loss: 0.0037
# Epoch 10/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0146 - val_loss: 0.0044
# Epoch 11/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0162 - val_loss: 0.0024
# Epoch 12/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0158 - val_loss: 0.0016
# Epoch 13/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0134 - val_loss: 0.0037
# Epoch 14/50
# 212/212 [==============================] - 4s 18ms/step - loss: 0.0128 - val_loss: 0.0012
# Epoch 15/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0139 - val_loss: 2.2876e-04
# Epoch 16/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0121 - val_loss: 3.5007e-05
# Epoch 17/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0138 - val_loss: 2.0192e-06
# Epoch 18/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0122 - val_loss: 0.0016
# Epoch 19/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0124 - val_loss: 6.8535e-05
# Epoch 20/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0121 - val_loss: 0.0017
# Epoch 21/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0110 - val_loss: 2.6304e-04
# Epoch 22/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0110 - val_loss: 2.7985e-04
# Epoch 23/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0090 - val_loss: 7.1323e-05
# Epoch 24/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0117 - val_loss: 6.7821e-04
# Epoch 25/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0130 - val_loss: 4.9462e-06
# Epoch 26/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0110 - val_loss: 0.0014
# Epoch 27/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 28/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0108 - val_loss: 9.0829e-06
# Epoch 29/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0091 - val_loss: 7.0422e-06
# Epoch 30/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0099 - val_loss: 6.4938e-04
# Epoch 31/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0081 - val_loss: 0.0016
# Epoch 32/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0090 - val_loss: 9.8394e-06
# Epoch 33/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0092 - val_loss: 3.3334e-06
# Epoch 34/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0088 - val_loss: 2.7445e-05
# Epoch 35/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 36/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0094 - val_loss: 1.4950e-04
# Epoch 37/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0086 - val_loss: 4.1178e-06
# Epoch 38/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0092 - val_loss: 8.0330e-06
# Epoch 39/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0081 - val_loss: 1.1242e-05
# Epoch 40/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0078 - val_loss: 3.8993e-06
# Epoch 41/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0101 - val_loss: 2.6490e-04
# Epoch 42/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0106 - val_loss: 0.0014
# Epoch 43/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0077 - val_loss: 0.0013
# Epoch 44/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0019
# Epoch 45/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0084 - val_loss: 0.0022
# Epoch 46/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0096 - val_loss: 5.7316e-05
# Epoch 47/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 9.1412e-05
# Epoch 48/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0082 - val_loss: 1.1907e-04
# Epoch 49/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0091 - val_loss: 9.2464e-04
# Epoch 50/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0076 - val_loss: 0.0011

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 6s 25ms/step - loss: 0.0693
# Epoch 2/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0302
# Epoch 3/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0288
# Epoch 4/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0243
# Epoch 5/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0223
# Epoch 6/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0215
# Epoch 7/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0193
# Epoch 8/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0181
# Epoch 9/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0175
# Epoch 10/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0159
# Epoch 11/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0186
# Epoch 12/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0200
# Epoch 13/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0167
# Epoch 14/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0163
# Epoch 15/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0157
# Epoch 16/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0163
# Epoch 17/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0149
# Epoch 18/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0156
# Epoch 19/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0157
# Epoch 20/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0138
# Epoch 21/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0144
# Epoch 22/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0117
# Epoch 23/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0131
# Epoch 24/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0138
# Epoch 25/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0131
# Epoch 26/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0129
# Epoch 27/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0120
# Epoch 28/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0130
# Epoch 29/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0143
# Epoch 30/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0129
# Epoch 31/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0116
# Epoch 32/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0131
# Epoch 33/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0109
# Epoch 34/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0129
# Epoch 35/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0114
# Epoch 36/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0127
# Epoch 37/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0123
# Epoch 38/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0110
# Epoch 39/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0108
# Epoch 40/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0113
# Epoch 41/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0115
# Epoch 42/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0126
# Epoch 43/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0100
# Epoch 44/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0118
# Epoch 45/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0110
# Epoch 46/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0107
# Epoch 47/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0113
# Epoch 48/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0105
# Epoch 49/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0107
# Epoch 50/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0101

# %%
from keras.models import load_model
forecast_model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[74.20702031],
#        [74.03159515],
#        [73.85584652],
#        [73.69618398],
#        [73.53917666],
#        [73.38575136],
#        [73.23537227],
#        [73.08984516],
#        [72.94848373],
#        [72.80984362],
#        [72.67695276],
#        [72.5523834 ],
#        [72.43309356],
#        [72.32046851],
#        [72.21408635],
#        [72.11189376],
#        [72.01483022],
#        [71.92383517],
#        [71.83871593]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
