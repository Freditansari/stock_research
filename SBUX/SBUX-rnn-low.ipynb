# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='SBUX'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 4s 18ms/step - loss: 0.0417 - val_loss: 0.0510
# Epoch 2/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0221 - val_loss: 0.0726
# Epoch 3/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0170 - val_loss: 0.0011
# Epoch 4/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0176 - val_loss: 0.0024
# Epoch 5/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0159 - val_loss: 0.0067
# Epoch 6/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0126 - val_loss: 8.2463e-04
# Epoch 7/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0138 - val_loss: 0.0017
# Epoch 8/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0126 - val_loss: 0.0011
# Epoch 9/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0105 - val_loss: 0.0102
# Epoch 10/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0105 - val_loss: 5.6982e-05
# Epoch 11/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0098 - val_loss: 7.6098e-04
# Epoch 12/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0105 - val_loss: 9.5738e-05
# Epoch 13/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0106 - val_loss: 0.0024
# Epoch 14/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0089 - val_loss: 1.3517e-04
# Epoch 15/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0112 - val_loss: 1.0591e-04
# Epoch 16/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0084 - val_loss: 0.0115
# Epoch 17/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0111 - val_loss: 9.0040e-04
# Epoch 18/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0082 - val_loss: 3.6946e-05
# Epoch 19/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0097 - val_loss: 9.7181e-04
# Epoch 20/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 7.3373e-05
# Epoch 21/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 22/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0080 - val_loss: 2.9937e-05
# Epoch 23/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0086 - val_loss: 0.0043
# Epoch 24/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0083 - val_loss: 8.6547e-04
# Epoch 25/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0088 - val_loss: 0.0031
# Epoch 26/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0069 - val_loss: 2.1122e-04
# Epoch 27/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0091 - val_loss: 6.1975e-04
# Epoch 28/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0077 - val_loss: 4.0679e-04
# Epoch 29/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0070 - val_loss: 8.3946e-04
# Epoch 30/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0103 - val_loss: 3.0484e-04
# Epoch 31/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0073 - val_loss: 0.0028
# Epoch 32/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0076 - val_loss: 5.6282e-05
# Epoch 33/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0067 - val_loss: 0.0024
# Epoch 34/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0075 - val_loss: 7.2072e-05
# Epoch 35/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0090 - val_loss: 4.7394e-04
# Epoch 36/50
# 212/212 [==============================] - 1s 7ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 37/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0075 - val_loss: 0.0053
# Epoch 38/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0073 - val_loss: 0.0049
# Epoch 39/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0105 - val_loss: 5.4380e-04
# Epoch 40/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0070 - val_loss: 0.0035
# Epoch 41/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0071 - val_loss: 2.7831e-05
# Epoch 42/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0074 - val_loss: 1.4011e-05
# Epoch 43/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0071 - val_loss: 8.0119e-05
# Epoch 44/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0062 - val_loss: 3.7631e-05
# Epoch 45/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 46/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0073 - val_loss: 3.1227e-04
# Epoch 47/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0077 - val_loss: 1.0251e-05
# Epoch 48/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0077 - val_loss: 8.2795e-04
# Epoch 49/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0078 - val_loss: 9.0542e-05
# Epoch 50/50
# 212/212 [==============================] - 2s 7ms/step - loss: 0.0086 - val_loss: 0.0012

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0570
# Epoch 2/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0281
# Epoch 3/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0253
# Epoch 4/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0182
# Epoch 5/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0151
# Epoch 6/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0176
# Epoch 7/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0167
# Epoch 8/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0137
# Epoch 9/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0162
# Epoch 10/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0131
# Epoch 11/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0122
# Epoch 12/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0115
# Epoch 13/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0131
# Epoch 14/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0115
# Epoch 15/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0118
# Epoch 16/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0106
# Epoch 17/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0120
# Epoch 18/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0106
# Epoch 19/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0145
# Epoch 20/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0133
# Epoch 21/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0136
# Epoch 22/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0110
# Epoch 23/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0113
# Epoch 24/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0097
# Epoch 25/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0110
# Epoch 26/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0126
# Epoch 27/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0118
# Epoch 28/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0100
# Epoch 29/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0117
# Epoch 30/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0102
# Epoch 31/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0129
# Epoch 32/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0097
# Epoch 33/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0112
# Epoch 34/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0135
# Epoch 35/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0100
# Epoch 36/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0114
# Epoch 37/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0099
# Epoch 38/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0101
# Epoch 39/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0110
# Epoch 40/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0094
# Epoch 41/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0105
# Epoch 42/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0100
# Epoch 43/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0098
# Epoch 44/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0099
# Epoch 45/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0091
# Epoch 46/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0113
# Epoch 47/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0102
# Epoch 48/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0080
# Epoch 49/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0102
# Epoch 50/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0092

# %%
from keras.models import load_model
forecast_model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[367.41047403],
#        [367.10916009],
#        [366.92836225],
#        [366.8080833 ],
#        [366.72623734],
#        [366.66957596],
#        [366.6296885 ],
#        [366.60145267],
#        [366.58127971],
#        [366.56678236],
#        [366.55649036],
#        [366.54902825],
#        [366.54349492],
#        [366.53951091],
#        [366.53674425],
#        [366.53489453],
#        [366.53340843],
#        [366.53222272],
#        [366.53143224]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
