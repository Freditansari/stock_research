# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='QQQ'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(150, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.5))
model.add(Dense(75, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='SGD', loss='mse')
# model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 5s 22ms/step - loss: 0.0621 - val_loss: 0.0678
# Epoch 2/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0371 - val_loss: 0.0324
# Epoch 3/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0324 - val_loss: 0.0336
# Epoch 4/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0306 - val_loss: 0.0084
# Epoch 5/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0293 - val_loss: 0.0132
# Epoch 6/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0271 - val_loss: 0.0077
# Epoch 7/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0270 - val_loss: 0.0229
# Epoch 8/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0276 - val_loss: 0.0164
# Epoch 9/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0229 - val_loss: 0.0063
# Epoch 10/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0265 - val_loss: 0.0350
# Epoch 11/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0273 - val_loss: 0.0030
# Epoch 12/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0221 - val_loss: 0.0181
# Epoch 13/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0223 - val_loss: 0.0042
# Epoch 14/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0224 - val_loss: 0.0032
# Epoch 15/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0263 - val_loss: 0.0058
# Epoch 16/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0247 - val_loss: 0.0109
# Epoch 17/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0240 - val_loss: 0.0032
# Epoch 18/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0211 - val_loss: 0.0037
# Epoch 19/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0230 - val_loss: 0.0064
# Epoch 20/50
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0236 - val_loss: 0.0382
# Epoch 21/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0216 - val_loss: 0.0094
# Epoch 22/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0232 - val_loss: 0.0132
# Epoch 23/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0214 - val_loss: 0.0089
# Epoch 24/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0215 - val_loss: 1.2771e-04
# Epoch 25/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0256 - val_loss: 0.0187
# Epoch 26/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0241 - val_loss: 0.0121
# Epoch 27/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0234 - val_loss: 0.0033
# Epoch 28/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0240 - val_loss: 0.0067
# Epoch 29/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0194 - val_loss: 0.0072
# Epoch 30/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0201 - val_loss: 0.0075
# Epoch 31/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0220 - val_loss: 0.0086
# Epoch 32/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0218 - val_loss: 0.0147
# Epoch 33/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0239 - val_loss: 0.0116
# Epoch 34/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0214 - val_loss: 0.0066
# Epoch 35/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0224 - val_loss: 0.0048
# Epoch 36/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0218 - val_loss: 0.0098
# Epoch 37/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0173 - val_loss: 0.0044
# Epoch 38/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0185 - val_loss: 0.0037
# Epoch 39/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0242 - val_loss: 0.0173
# Epoch 40/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0188 - val_loss: 5.0073e-04
# Epoch 41/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0174 - val_loss: 0.0098
# Epoch 42/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0214 - val_loss: 0.0098
# Epoch 43/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0191 - val_loss: 0.0036
# Epoch 44/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0206 - val_loss: 0.0040
# Epoch 45/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0204 - val_loss: 0.0129
# Epoch 46/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0199 - val_loss: 0.0072
# Epoch 47/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0199 - val_loss: 0.0100
# Epoch 48/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0176 - val_loss: 0.0061
# Epoch 49/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0212 - val_loss: 0.0034
# Epoch 50/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0178 - val_loss: 0.0017

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(150, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.5))
forecast_model.add(Dense(75, activation='relu'))
forecast_model.add(Dropout(0.5))
forecast_model.add(Dense(20, activation='relu'))
forecast_model.add(Dropout(0.5))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 5s 22ms/step - loss: 0.0569
# Epoch 2/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0387
# Epoch 3/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0320
# Epoch 4/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0265
# Epoch 5/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0226
# Epoch 6/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0242
# Epoch 7/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0248
# Epoch 8/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0217
# Epoch 9/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0225
# Epoch 10/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0219
# Epoch 11/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0214
# Epoch 12/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0205
# Epoch 13/50
# 232/232 [==============================] - 5s 19ms/step - loss: 0.0249
# Epoch 14/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0211
# Epoch 15/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0231
# Epoch 16/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0206
# Epoch 17/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0235
# Epoch 18/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0194
# Epoch 19/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0206
# Epoch 20/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0230
# Epoch 21/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0205
# Epoch 22/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0240
# Epoch 23/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0191
# Epoch 24/50
# 232/232 [==============================] - 5s 20ms/step - loss: 0.0222
# Epoch 25/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0215
# Epoch 26/50
# 232/232 [==============================] - 4s 15ms/step - loss: 0.0214
# Epoch 27/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0215
# Epoch 28/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0169
# Epoch 29/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0191
# Epoch 30/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0177
# Epoch 31/50
# 232/232 [==============================] - 4s 19ms/step - loss: 0.0208
# Epoch 32/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0239
# Epoch 33/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0178
# Epoch 34/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0207
# Epoch 35/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0195
# Epoch 36/50
# 231/232 [============================>.] - ETA: 0s - loss: 0.022232/232 [==============================] - 4s 17ms/step - loss: 0.0222
# Epoch 37/50
# 232/232 [==============================] - 4s 17ms/step - loss: 0.0209
# Epoch 38/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0188
# Epoch 39/50
# 232/232 [==============================] - 4s 16ms/step - loss: 0.0213
# Epoch 40/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0229
# Epoch 41/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0198
# Epoch 42/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0168
# Epoch 43/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0169
# Epoch 44/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0178
# Epoch 45/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0176
# Epoch 46/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0179
# Epoch 47/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0171
# Epoch 48/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0167
# Epoch 49/50
# 232/232 [==============================] - 3s 15ms/step - loss: 0.0189
# Epoch 50/50
# 232/232 [==============================] - 3s 14ms/step - loss: 0.0189

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[208.48936054],
#        [207.67689574],
#        [206.91587127],
#        [206.21247571],
#        [205.55521539],
#        [204.94610668],
#        [204.3574828 ],
#        [203.79862236],
#        [203.27222653],
#        [202.77657063],
#        [202.27596894],
#        [201.80136853],
#        [201.34287784],
#        [200.90171006],
#        [200.47798354],
#        [200.06687511],
#        [199.67214693],
#        [199.28919985],
#        [198.91434356]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
# todo 
# add save charts 
# add save forecast.csv
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
