# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='NVDA'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
# model.add(Dense(50, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 4s 21ms/step - loss: 0.0463 - val_loss: 0.0800
# Epoch 2/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0244 - val_loss: 0.0686
# Epoch 3/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0197 - val_loss: 0.0098
# Epoch 4/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0169 - val_loss: 0.0023
# Epoch 5/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0154 - val_loss: 0.0028
# Epoch 6/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0144 - val_loss: 1.0556e-04
# Epoch 7/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0152 - val_loss: 0.0019
# Epoch 8/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0134 - val_loss: 0.0032
# Epoch 9/50
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0113 - val_loss: 0.0055
# Epoch 10/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0128 - val_loss: 0.0080
# Epoch 11/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0028
# Epoch 12/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0123 - val_loss: 0.0078
# Epoch 13/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0113 - val_loss: 9.3898e-05
# Epoch 14/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0120 - val_loss: 1.6626e-07
# Epoch 15/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0128 - val_loss: 5.0266e-04
# Epoch 16/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0126 - val_loss: 1.1549e-04
# Epoch 17/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0137 - val_loss: 0.0040
# Epoch 18/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0130 - val_loss: 0.0023
# Epoch 19/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0103 - val_loss: 2.6588e-04
# Epoch 20/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0104 - val_loss: 0.0014
# Epoch 21/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0108 - val_loss: 0.0038
# Epoch 22/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0094 - val_loss: 0.0011
# Epoch 23/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0116 - val_loss: 0.0047
# Epoch 24/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0121 - val_loss: 0.0017
# Epoch 25/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0108 - val_loss: 0.0017
# Epoch 26/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0100 - val_loss: 7.5687e-04
# Epoch 27/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0111 - val_loss: 0.0017
# Epoch 28/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0112 - val_loss: 0.0010
# Epoch 29/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 3.4135e-04
# Epoch 30/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0088 - val_loss: 2.1827e-05
# Epoch 31/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0102 - val_loss: 2.6756e-04
# Epoch 32/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0092 - val_loss: 8.8940e-04
# Epoch 33/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0109 - val_loss: 6.5619e-04
# Epoch 34/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0097 - val_loss: 0.0021
# Epoch 35/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0108 - val_loss: 7.9422e-04
# Epoch 36/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0086 - val_loss: 5.1792e-05
# Epoch 37/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0108 - val_loss: 0.0016
# Epoch 38/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0114 - val_loss: 3.2184e-05
# Epoch 39/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0099 - val_loss: 8.4449e-04
# Epoch 40/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 9.9489e-05
# Epoch 41/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0104 - val_loss: 1.6541e-05
# Epoch 42/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0104 - val_loss: 1.4745e-04
# Epoch 43/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0093 - val_loss: 8.9541e-06
# Epoch 44/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0104 - val_loss: 5.3941e-05
# Epoch 45/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0100 - val_loss: 0.0023
# Epoch 46/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0099 - val_loss: 0.0077
# Epoch 47/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0097 - val_loss: 1.4134e-05
# Epoch 48/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0098 - val_loss: 8.4656e-04
# Epoch 49/50
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0100 - val_loss: 4.7333e-04
# Epoch 50/50
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0089 - val_loss: 3.7703e-04

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
predictions.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'_predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 4s 18ms/step - loss: 0.0872
# Epoch 2/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0567
# Epoch 3/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0486
# Epoch 4/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0382
# Epoch 5/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0250
# Epoch 6/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0236
# Epoch 7/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0193
# Epoch 8/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0192
# Epoch 9/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0196
# Epoch 10/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0156
# Epoch 11/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0177
# Epoch 12/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0196
# Epoch 13/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0151
# Epoch 14/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0147
# Epoch 15/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0125
# Epoch 16/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0142
# Epoch 17/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0142
# Epoch 18/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0099
# Epoch 19/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0136
# Epoch 20/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0136
# Epoch 21/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0129
# Epoch 22/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0117
# Epoch 23/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0135
# Epoch 24/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0134
# Epoch 25/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0141
# Epoch 26/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0119
# Epoch 27/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0127
# Epoch 28/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0099
# Epoch 29/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0117
# Epoch 30/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0078
# Epoch 31/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0122
# Epoch 32/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0127
# Epoch 33/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0101
# Epoch 34/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0116
# Epoch 35/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0131
# Epoch 36/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0113
# Epoch 37/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0107
# Epoch 38/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0123
# Epoch 39/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0113
# Epoch 40/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0109
# Epoch 41/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0123
# Epoch 42/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0117
# Epoch 43/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0126
# Epoch 44/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0127
# Epoch 45/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110
# Epoch 46/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0119
# Epoch 47/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0125
# Epoch 48/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110
# Epoch 49/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0110
# Epoch 50/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0125

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[282.11147054],
#        [281.02128499],
#        [279.91833494],
#        [278.83669595],
#        [277.7774552 ],
#        [276.74198176],
#        [275.75380134],
#        [274.81692045],
#        [273.93364435],
#        [273.09902027],
#        [272.30087764],
#        [271.52625065],
#        [270.79497056],
#        [270.10228592],
#        [269.44747194],
#        [268.83808864],
#        [268.26355601],
#        [267.72507197],
#        [267.21588182]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
