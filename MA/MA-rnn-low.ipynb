# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing;
from sklearn.model_selection import cross_validate as cross_validation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
import datetime
from datetime import timedelta
forecast_out = 365 #Days from now

stock_ticker ='MA'
stock_parameter ='Low'
epoch_number=50
epoch_number_forecast=50

end = datetime.datetime.now()#-timedelta(7) #remove timedetla -1 to go to productions mode
start = datetime.datetime.now()-timedelta(forecast_out)

# benchmark = web.DataReader(stock_ticker, 'yahoo', start, end )
stock = web.DataReader(stock_ticker, 'yahoo', start, end)

# %%
test_size=20
test_index = len(stock[stock_parameter])- test_size

# %%
train = stock[stock_parameter].iloc[:test_index]
test= stock[stock_parameter].iloc[test_index:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaler.fit(train.to_frame())
scaled_train = scaler.transform(train.to_frame())
scaled_test = scaler.transform(test.to_frame())

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length=test_size-1
generator = TimeseriesGenerator(scaled_train,scaled_train, length=length, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
n_features =1
model= Sequential()
# pretty good model at 200 epochs
# model.add(LSTM(50, activation='relu', input_shape=(length, n_features)))
# model.add(Dropout(0.2))
# model.add(Dense(25, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(10, activation='relu'))
# model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dropout(0.2))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(15, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='SGD', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=1)

# %%
validation_generator= TimeseriesGenerator(scaled_test, scaled_test,
                                          length=length, batch_size =1)

# %%
# model.fit_generator(generator, epochs=20,
#                    validation_data=validation_generator, callbacks=[early_stop])
model.fit_generator(generator, epochs=epoch_number,
                   validation_data=validation_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f6d1fd591d10>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 212 steps, validate for 1 steps
# Epoch 1/50
# 212/212 [==============================] - 15s 72ms/step - loss: 0.0509 - val_loss: 0.0012
# Epoch 2/50
# 212/212 [==============================] - 4s 18ms/step - loss: 0.0294 - val_loss: 0.0041
# Epoch 3/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0234 - val_loss: 0.0014
# Epoch 4/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0229 - val_loss: 0.0046
# Epoch 5/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0196 - val_loss: 0.0012
# Epoch 6/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0186 - val_loss: 3.1686e-04
# Epoch 7/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0144 - val_loss: 2.1379e-04
# Epoch 8/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0142 - val_loss: 3.5578e-05
# Epoch 9/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0156 - val_loss: 1.9238e-05
# Epoch 10/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0150 - val_loss: 1.7223e-04
# Epoch 11/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0116 - val_loss: 1.1229e-07
# Epoch 12/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0117 - val_loss: 5.2839e-04
# Epoch 13/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0144 - val_loss: 7.4585e-04
# Epoch 14/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0111 - val_loss: 4.2767e-04
# Epoch 15/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0130 - val_loss: 0.0011
# Epoch 16/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0130 - val_loss: 3.0298e-04
# Epoch 17/50
# 212/212 [==============================] - 5s 22ms/step - loss: 0.0117 - val_loss: 5.3127e-05
# Epoch 18/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0123 - val_loss: 5.7892e-05
# Epoch 19/50
# 212/212 [==============================] - 4s 21ms/step - loss: 0.0124 - val_loss: 8.8771e-05
# Epoch 20/50
# 212/212 [==============================] - 4s 19ms/step - loss: 0.0120 - val_loss: 1.9577e-05
# Epoch 21/50
# 212/212 [==============================] - 4s 21ms/step - loss: 0.0115 - val_loss: 5.3791e-04
# Epoch 22/50
# 212/212 [==============================] - 4s 20ms/step - loss: 0.0107 - val_loss: 2.7874e-05
# Epoch 23/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0132 - val_loss: 1.1161e-04
# Epoch 24/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0106 - val_loss: 7.8285e-04
# Epoch 25/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0127 - val_loss: 8.0911e-06
# Epoch 26/50
# 212/212 [==============================] - 3s 15ms/step - loss: 0.0130 - val_loss: 6.1463e-04
# Epoch 27/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0088 - val_loss: 0.0017
# Epoch 28/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0111 - val_loss: 4.7830e-04
# Epoch 29/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0109 - val_loss: 0.0011
# Epoch 30/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0103 - val_loss: 0.0011
# Epoch 31/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0102 - val_loss: 0.0010
# Epoch 32/50
# 212/212 [==============================] - 4s 18ms/step - loss: 0.0113 - val_loss: 4.9991e-04
# Epoch 33/50
# 212/212 [==============================] - 4s 18ms/step - loss: 0.0097 - val_loss: 0.0012
# Epoch 34/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0106 - val_loss: 3.4988e-05
# Epoch 35/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0099 - val_loss: 2.2526e-05
# Epoch 36/50
# 212/212 [==============================] - 3s 16ms/step - loss: 0.0103 - val_loss: 3.5524e-04
# Epoch 37/50
# 212/212 [==============================] - 4s 17ms/step - loss: 0.0105 - val_loss: 2.1211e-04
# Epoch 38/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0096 - val_loss: 2.4405e-04
# Epoch 39/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0118 - val_loss: 5.5239e-04
# Epoch 40/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0120 - val_loss: 2.0498e-08
# Epoch 41/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0102 - val_loss: 0.0010
# Epoch 42/50
# 212/212 [==============================] - 3s 14ms/step - loss: 0.0094 - val_loss: 2.2162e-04
# Epoch 43/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0117 - val_loss: 1.0667e-04
# Epoch 44/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0101 - val_loss: 2.3915e-04
# Epoch 45/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0090 - val_loss: 1.3029e-04
# Epoch 46/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0103 - val_loss: 2.6203e-04
# Epoch 47/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0103 - val_loss: 2.5517e-04
# Epoch 48/50
# 212/212 [==============================] - 3s 13ms/step - loss: 0.0115 - val_loss: 6.2043e-05
# Epoch 49/50
# 212/212 [==============================] - 3s 12ms/step - loss: 0.0099 - val_loss: 7.4893e-05
# Epoch 50/50
# 212/212 [==============================] - 2s 12ms/step - loss: 0.0081 - val_loss: 3.3419e-05

# %%
losses= pd.DataFrame(model.history.history)
ax =losses.plot()
losses.plot(ax=ax)
plt.savefig(stock_ticker+'_'+stock_parameter+'loss_chart.png')

# %%
test_predictions =[]
first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))
for i in range(len(test)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]], axis=1)

# %%
true_predictions =scaler.inverse_transform(test_predictions)

# %%
predictions = pd.DataFrame(test)
predictions['Predictions'] = true_predictions

# %%
ax=predictions.plot(figsize=(12,8))
plt.show()
plt.savefig(stock_ticker+'_'+stock_parameter+'predictions_chart.png')

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'prediction'+'.h5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(stock[stock_parameter].to_frame())

# %%
length=19
generator=TimeseriesGenerator(scaled_full_data, scaled_full_data, length=length, batch_size=1)

# %%
forecast_model= Sequential()
forecast_model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(50, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(15, activation='relu'))
forecast_model.add(Dropout(0.2))
forecast_model.add(Dense(1, activation='relu'))
forecast_model.compile(optimizer='SGD', loss='mse')
forecast_model.fit_generator(generator, epochs=epoch_number_forecast)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 232 steps
# Epoch 1/50
# 232/232 [==============================] - 7s 31ms/step - loss: 0.0494
# Epoch 2/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0238
# Epoch 3/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0226
# Epoch 4/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0181
# Epoch 5/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0159
# Epoch 6/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0168
# Epoch 7/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0138
# Epoch 8/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0140
# Epoch 9/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0149
# Epoch 10/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0114
# Epoch 11/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0126
# Epoch 12/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0131
# Epoch 13/50
# 232/232 [==============================] - 3s 13ms/step - loss: 0.0108
# Epoch 14/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0111
# Epoch 15/50
# 232/232 [==============================] - 3s 12ms/step - loss: 0.0106
# Epoch 16/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0109
# Epoch 17/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0112
# Epoch 18/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0113
# Epoch 19/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0100
# Epoch 20/50
# 232/232 [==============================] - 3s 11ms/step - loss: 0.0108
# Epoch 21/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0108
# Epoch 22/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0105
# Epoch 23/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0098
# Epoch 24/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0107
# Epoch 25/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0099
# Epoch 26/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0104
# Epoch 27/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0101
# Epoch 28/50
# 232/232 [==============================] - 2s 11ms/step - loss: 0.0098
# Epoch 29/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0077
# Epoch 30/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0104
# Epoch 31/50
# 232/232 [==============================] - 2s 10ms/step - loss: 0.0102
# Epoch 32/50
# 232/232 [==============================] - 2s 9ms/step - loss: 0.0093
# Epoch 33/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0098
# Epoch 34/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0099
# Epoch 35/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0089
# Epoch 36/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0089
# Epoch 37/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0093
# Epoch 38/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0104
# Epoch 39/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0105
# Epoch 40/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0098
# Epoch 41/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0085
# Epoch 42/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0099
# Epoch 43/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0081
# Epoch 44/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0092
# Epoch 45/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0102
# Epoch 46/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0093
# Epoch 47/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0085
# Epoch 48/50
# 232/232 [==============================] - 2s 7ms/step - loss: 0.0084
# Epoch 49/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0087
# Epoch 50/50
# 232/232 [==============================] - 2s 8ms/step - loss: 0.0087

# %%
from keras.models import load_model
model.save(stock_ticker+'_'+stock_parameter+'forecast'+'.h5')

# %%
forecast =[]

periods=19

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    forecast.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[268.51383554],
#        [269.17837362],
#        [269.81610062],
#        [270.43333354],
#        [271.03300982],
#        [271.61413896],
#        [272.23676641],
#        [272.92841314],
#        [273.64635657],
#        [274.38508741],
#        [275.14912023],
#        [275.94276553],
#        [276.76237596],
#        [277.61116528],
#        [278.49694682],
#        [279.42519589],
#        [280.41870636],
#        [281.4527374 ],
#        [282.25836203]])

# %%
from datetime import date
forecast_index = pd.date_range(start=date.today(), periods = periods, freq="D")

# %%
forecast_df = pd.DataFrame(data = forecast, index=forecast_index, columns=['Forecast'])

# %%
ax=stock[stock_parameter].plot()
forecast_df.plot(ax=ax)
plt.xlim( datetime.datetime.now()-timedelta(periods), datetime.datetime.now())
plt.savefig(stock_ticker+'_'+stock_parameter+'forecast_chart.png')

# %%
forecast_df.to_csv('forecast_'+stock_ticker+'_'+stock_parameter+'.csv')
